# %%
import math as m
import csv
import matplotlib.pyplot as plt
import igraph

# %%
csv_file_url_1 = '../cwm1-steinschlagrisiko/data/out_1.csv'
csv_file_url_2 = '../cwm1-steinschlagrisiko/data/out_2.csv'

# %%
#returns a list with all the rows
def getRows(url) -> list:
    rows = []
    with open(url, mode='r') as file:
        csv_reader = csv.DictReader(file)
        for row in csv_reader:
            rows.append(row)
    return rows

# %%
def main():
    print('hello world')
    plt.scatter([1,2,3,4,5], [9,8,7,6,5])
    # plt.plot()

# %%
main()
# Out:
# hello world
